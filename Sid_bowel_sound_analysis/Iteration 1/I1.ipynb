# %% [markdown]
# # Iteration 1:

# %% [markdown]
# ## I1 R1: Excel File Reader

# %%
# Import the library

import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Mount Google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# set path to data file
path_to_data = "/content/drive/My Drive/CP5046 ICT1 Project folder_Group2 Junyu Siddhanth/Siddhanth/Dev Package/Data/Test_Data_Siddhanth.xlsx"

# %%
# Read the annotation data from the right worksheet of the Excel file. 
df = pd.read_excel(path_to_data)   # df = DataFrame

# Using pandas library, the dataset is viewed through a dataframe.
df
# Out:
#    Filename  PatientNo  Threshold Label (A=Pre/B=Post)  Age in days Gender  \
# 0       1.0        1.0    0.00050                    A          2.0      M
# 1       2.0        2.0    0.00010                    B          2.0      M
# 2       3.0        3.0    0.00020                    A          2.0      M
# 3       4.0        4.0    0.00005                    B          3.0      M
# 4       5.0        5.0    0.00040                    A          3.0      M
#
#   Sick baby                                            Disease  Confidence  \
# 0         y  UNILATERAL MULTICYSTIC KIDNEY AND PYELETASIS, ...         5.0
# 1         y  UNILATERAL MULTICYSTIC KIDNEY AND PYELETASIS, ...         5.0
# 2         Y           SHOLDER DYSTOCIA, RESP DISTRESS, MEC LIQ         5.0
# 3         Y  MEC LIQ,L)FETAL KIDNEY LOW IN PELVIS,IUGR<(5%ILE)         4.0
# 4         y  MEC LIQ,L)FETAL KIDNEY LOW IN PELVIS,IUGR<(5%ILE)         4.0
#
# ...

# %%
data_index = df.keys()

# print all columns/attributes in the test dataset
col_list = [colName for colName in data_index]
col_list
# Out:
# ['Filename',
#  'PatientNo',
#  'Threshold',
#  'Label (A=Pre/B=Post)',
#  'Age in days',
#  'Gender',
#  'Sick baby',
#  'Disease',
#  'Confidence',
#  'S1',
#  'E1',
#  'S2',
#  'E2',
#  'S3',
#  'E3',
#  'S4',
#  'E4',
#  'S5',
#  'E5',
#  'Note',
#  'tick_num',
#  'tick_rate_min',
#  'tick_int',
#  'tick_dur',
#  'tick_int_std',
#  'tick_dur_std']

# %%
# Iterate through all columns of a row:
rowNo = 0 # check row 0
for colname in data_index:  # iterate through each column name of the DataFrame
  print(colname, rowNo, df[colname][rowNo]) # we can access a cell value using the key name and row number like this
# Out:
# Filename 0 1.0
# PatientNo 0 1.0
# Threshold 0 0.0005
# Label (A=Pre/B=Post) 0 A
# Age in days 0 2.0
# Gender 0 M
# Sick baby 0 y
# Disease 0 UNILATERAL MULTICYSTIC KIDNEY AND PYELETASIS, IUGR<(3%IILE),FETAL BRADYCARDIA
# Confidence 0 5.0
# S1 0 1.0
# E1 0 2.0
# S2 0 3.0
# E2 0 4.0
# S3 0 5.0
# E3 0 6.0
# S4 0 7.0
# E4 0 8.0
# S5 0 9.0
# E5 0 10.0
# Note 0 11.0
# tick_num 0 12.0
# tick_rate_min 0 13.0
# tick_int 0 14.0
# tick_dur 0 15.0
# tick_int_std 0 16.0
# tick_dur_std 0 17.0

# %% [markdown]
# ## I1 R2: Export the test dataframe to result excel file

# %%
# set path to result file
path_to_result = "/content/drive/My Drive/CP5046 ICT1 Project folder_Group2 Junyu Siddhanth/Siddhanth/Dev Package/Data/Test_Data_Result_(1).xlsx"

# export df to result path excel file
df.to_excel(path_to_result, index=False)

# read result excel file in new dataframe
df_result = pd.read_excel(path_to_result)
df_result
# Out:
#    Filename  PatientNo  Threshold Label (A=Pre/B=Post)  Age in days Gender  \
# 0         1          1    0.00050                    A            2      M
# 1         2          2    0.00010                    B            2      M
# 2         3          3    0.00020                    A            2      M
# 3         4          4    0.00005                    B            3      M
# 4         5          5    0.00040                    A            3      M
#
#   Sick baby                                            Disease  Confidence  \
# 0         y  UNILATERAL MULTICYSTIC KIDNEY AND PYELETASIS, ...           5
# 1         y  UNILATERAL MULTICYSTIC KIDNEY AND PYELETASIS, ...           5
# 2         Y           SHOLDER DYSTOCIA, RESP DISTRESS, MEC LIQ           5
# 3         Y  MEC LIQ,L)FETAL KIDNEY LOW IN PELVIS,IUGR<(5%ILE)           4
# 4         y  MEC LIQ,L)FETAL KIDNEY LOW IN PELVIS,IUGR<(5%ILE)           4
#
# ...

# %% [markdown]
# ## I1 R3: Check if the result data is exported and loaded correctly

# %%
# compare all values in each row and column
comparison_values = df.values == df_result.iloc[:, :26].values   # values of result data after 26 column is new measurements, hence ignored.

comparison_values
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %% [markdown]
# Hence, data is exported and parsed correctly.
