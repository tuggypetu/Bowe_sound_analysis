# %% [markdown]
# Scope of Alpha Release:
#
# **Iteration 1**- Annotation file parser for Bowel Sound Analysis
#
# R1: Read the test data excel file in google collab, python
#
# R2: Export the test dataframe to result excel file
#
# R3: Check if the result is exported and loaded correctly
#
# **Iteration 2**- Dataset and generate clinical measurements calculations
#
# R1: Test data populator
#
# R2: Clinical measurements calculator
#
# R3: Calculate Bowel sound rate and Average duration of a Bowel sound
#
# **Iteration 3**- Data Analysis- Plotter and Prediction models
#
# R1: Exploratory Data Analysis- Graph plots
#
# R2: Linear Regression model
#
# R3: Logistic Regression model
